# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from seaborn import heatmap

# %%
df1 = pd.read_csv('D:\\BITS PILANI\\Applied Statistical Methods\\Assignment - 2\\Rajasthan1\\15396_26.65_71.65_2000.csv')
df2 = pd.read_csv('D:\\BITS PILANI\\Applied Statistical Methods\\Assignment - 2\\Rajasthan1\\15396_26.65_71.65_2001.csv')
df3 = pd.read_csv('D:\\BITS PILANI\\Applied Statistical Methods\\Assignment - 2\\Rajasthan1\\15396_26.65_71.65_2002.csv')
df4 = pd.read_csv('D:\\BITS PILANI\\Applied Statistical Methods\\Assignment - 2\\Rajasthan1\\15396_26.65_71.65_2003.csv')
df5 = pd.read_csv('D:\\BITS PILANI\\Applied Statistical Methods\\Assignment - 2\\Rajasthan1\\15396_26.65_71.65_2004.csv')
df6 = pd.read_csv('D:\\BITS PILANI\\Applied Statistical Methods\\Assignment - 2\\Rajasthan1\\15396_26.65_71.65_2005.csv')
df7 = pd.read_csv('D:\\BITS PILANI\\Applied Statistical Methods\\Assignment - 2\\Rajasthan1\\15396_26.65_71.65_2006.csv')
df8 = pd.read_csv('D:\\BITS PILANI\\Applied Statistical Methods\\Assignment - 2\\Rajasthan1\\15396_26.65_71.65_2007.csv')
df9 = pd.read_csv('D:\\BITS PILANI\\Applied Statistical Methods\\Assignment - 2\\Rajasthan1\\15396_26.65_71.65_2008.csv')
df10 = pd.read_csv('D:\\BITS PILANI\\Applied Statistical Methods\\Assignment - 2\\Rajasthan1\\15396_26.65_71.65_2009.csv')
df11 = pd.read_csv('D:\\BITS PILANI\\Applied Statistical Methods\\Assignment - 2\\Rajasthan1\\15396_26.65_71.65_2010.csv')
df12 = pd.read_csv('D:\\BITS PILANI\\Applied Statistical Methods\\Assignment - 2\\Rajasthan1\\15396_26.65_71.65_2011.csv')
df13 = pd.read_csv('D:\\BITS PILANI\\Applied Statistical Methods\\Assignment - 2\\Rajasthan1\\15396_26.65_71.65_2012.csv')
df14 = pd.read_csv('D:\\BITS PILANI\\Applied Statistical Methods\\Assignment - 2\\Rajasthan1\\15396_26.65_71.65_2013.csv')
df15 = pd.read_csv('D:\\BITS PILANI\\Applied Statistical Methods\\Assignment - 2\\Rajasthan1\\15396_26.65_71.65_2014.csv')

# %%
df = df1.append(df2)
df = df.append(df3)
df = df.append(df4)
df = df.append(df5)
df = df.append(df6)
df = df.append(df7)
df = df.append(df8)
df = df.append(df9)
df = df.append(df10)
df = df.append(df11)
df = df.append(df12)
df = df.append(df13)
df = df.append(df14)
df = df.append(df15)
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_612/644675653.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append(df2)
# C:\Users\HP\AppData\Local\Temp/ipykernel_612/644675653.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df3)
# C:\Users\HP\AppData\Local\Temp/ipykernel_612/644675653.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df4)
# C:\Users\HP\AppData\Local\Temp/ipykernel_612/644675653.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df5)
# ...

# %%
df.head()
# Out:
#   Source Location ID City State Country Latitude Longitude Time Zone  \
# 0  NSRDB       15396    -     -       -    26.65     71.65       5.5
# 1   Year       Month  Day  Hour  Minute      DHI       DNI       GHI
# 2   2000           1    1     0       0        0         0         0
# 3   2000           1    1     1       0        0         0         0
# 4   2000           1    1     2       0        0         0         0
#
#       Elevation Local Time Zone  ... Wind Direction Units Wind Speed  \
# 0             0             5.5  ...              Degrees        m/s
# 1  Clearsky DHI    Clearsky DNI  ...                  NaN        NaN
# 2             0               0  ...                  NaN        NaN
# 3             0               0  ...                  NaN        NaN
# 4             0               0  ...                  NaN        NaN
#
#   Snow Depth Units Fill Flag 0    Fill Flag 1     Fill Flag 2  \
# 0                m         NaN  Missing Image  Low Irradiance
# ...

# %%
df.iloc[1].values
df.columns = df.iloc[1].values
df = df.drop([0,1], axis=0)

# %%
df.head()
# Out:
#    Year Month Day Hour Minute DHI DNI GHI Clearsky DHI Clearsky DNI  ...  NaN  \
# 2  2000     1   1    0      0   0   0   0            0            0  ...  NaN
# 3  2000     1   1    1      0   0   0   0            0            0  ...  NaN
# 4  2000     1   1    2      0   0   0   0            0            0  ...  NaN
# 5  2000     1   1    3      0   0   0   0            0            0  ...  NaN
# 6  2000     1   1    4      0   0   0   0            0            0  ...  NaN
#
#    NaN  NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2  NaN  NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3  NaN  NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4  NaN  NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 5  NaN  NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 6  NaN  NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 35 columns]

# %%
df_new = pd.DataFrame(df[['Year', 'DHI',	'DNI', 'GHI', 'Clearsky DHI', 'Clearsky DNI', 'Clearsky GHI']])
df_new.head()
df_new = df_new.astype(int)
df_new.dtypes
type(df_new)
# Out:
# pandas.core.frame.DataFrame

# %%
df_new.reset_index()
df_new = df_new.drop(columns='Year')

# %%
corrmatrix = df_new.corr()
corrmatrix
# Out:
#                    DHI       DNI       GHI  Clearsky DHI  Clearsky DNI  \
# DHI           1.000000  0.810126  0.927168      0.978921      0.897983
# DNI           0.810126  1.000000  0.940300      0.840339      0.947746
# GHI           0.927168  0.940300  1.000000      0.940370      0.938249
# Clearsky DHI  0.978921  0.840339  0.940370      1.000000      0.898374
# Clearsky DNI  0.897983  0.947746  0.938249      0.898374      1.000000
# Clearsky GHI  0.952093  0.902440  0.985022      0.959677      0.949993
#
#               Clearsky GHI
# DHI               0.952093
# DNI               0.902440
# GHI               0.985022
# Clearsky DHI      0.959677
# Clearsky DNI      0.949993
# Clearsky GHI      1.000000

# %%
heatmap(data=corrmatrix, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h1>Data Cleaning

# %%
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.arima_process import ArmaProcess
from statsmodels.stats.diagnostic import acorr_ljungbox
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import pacf
from statsmodels.tsa.stattools import acf
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from itertools import product

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
# Out:
# d:\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# d:\Python\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,

# %%
data = df14.append(df15)

# %%
data.reset_index(inplace=True)

# %%
data.head()
data.drop(columns='index')
# Out:
#       Source Location ID City State Country Latitude Longitude Time Zone  \
# 0      NSRDB       15396    -     -       -    26.65     71.65       5.5
# 1       Year       Month  Day  Hour  Minute      DHI       DNI       GHI
# 2       2013           1    1     0       0        0         0         0
# 3       2013           1    1     1       0        0         0         0
# 4       2013           1    1     2       0        0         0         0
# ...      ...         ...  ...   ...     ...      ...       ...       ...
# 17519   2014          12   31    19       0        0         0         0
# 17520   2014          12   31    20       0        0         0         0
# 17521   2014          12   31    21       0        0         0         0
# 17522   2014          12   31    22       0        0         0         0
# 17523   2014          12   31    23       0        0         0         0
#
#           Elevation Local Time Zone  ... Wind Direction Units Wind Speed  \
# ...

# %%
data.columns = data.iloc[1].values
data.drop([0,1], axis=0, inplace=True)
data.head()
# Out:
#    1  Year Month Day Hour Minute DHI DNI GHI Clearsky DHI  ...  NaN  NaN  NaN  \
# 2  2  2013     1   1    0      0   0   0   0            0  ...  NaN  NaN  NaN
# 3  3  2013     1   1    1      0   0   0   0            0  ...  NaN  NaN  NaN
# 4  4  2013     1   1    2      0   0   0   0            0  ...  NaN  NaN  NaN
# 5  5  2013     1   1    3      0   0   0   0            0  ...  NaN  NaN  NaN
# 6  6  2013     1   1    4      0   0   0   0            0  ...  NaN  NaN  NaN
#
#   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2 NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3 NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4 NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 5 NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 6 NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 36 columns]

# %%
data.drop(1, axis=1, inplace=True)
data.head()
# Out:
#    Year Month Day Hour Minute DHI DNI GHI Clearsky DHI Clearsky DNI  ...  NaN  \
# 2  2013     1   1    0      0   0   0   0            0            0  ...  NaN
# 3  2013     1   1    1      0   0   0   0            0            0  ...  NaN
# 4  2013     1   1    2      0   0   0   0            0            0  ...  NaN
# 5  2013     1   1    3      0   0   0   0            0            0  ...  NaN
# 6  2013     1   1    4      0   0   0   0            0            0  ...  NaN
#
#    NaN  NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2  NaN  NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3  NaN  NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4  NaN  NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 5  NaN  NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 6  NaN  NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 35 columns]

# %%
data.reset_index(inplace=True)

# %%
data.drop(columns=['index'], inplace=True)

# %%
data_new = pd.DataFrame(data[['Year','Month','Day','Hour','Minute','DHI','DNI','GHI','Clearsky DHI','Clearsky DNI','Clearsky GHI','Dew Point','Temperature','Pressure','Relative Humidity','Solar Zenith Angle','Wind Speed']])

# %%
data_new.to_csv('D:\BITS PILANI\Applied Statistical Methods\Assignment - 2\Appended.csv')

# %%
df.to_csv('D:\BITS PILANI\Applied Statistical Methods\Assignment - 2\Combined.csv')
